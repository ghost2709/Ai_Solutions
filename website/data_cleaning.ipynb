# %%
classDiagram
    %% Abstract Classes
    class Person {
        <<abstract>>
        +String name
        +String address
        +String phone
        +String email
    }
    
    class Vehicle {
        <<abstract>>
        +String vehicleID
        +String make
        +String model
        +Int year
        +String status
        +display() String
        +getDetails() String
    }
    
    %% Inheritance from Person
    Person <|-- Customer
    Person <|-- Employee
    
    class Customer {
        +String customerID
        +String licenseNumber
        +rentVehicle(Vehicle) Rental
        +returnVehicle(Rental) Boolean
    }
    
    class Employee {
        +String employeeID
        +String position
        +processRental(Rental) Boolean
        +recordMaintenance(Vehicle, String) MaintenanceLog
    }
    
    %% Inheritance from Vehicle
    Vehicle <|-- Car
    Vehicle <|-- Truck
    Vehicle <|-- Bike
    
    class Car {
        +String fuelType
        +Int capacity
        +Float trunkSize
        +calculateRentalCost(days) Float
    }
    
    class Truck {
        +String fuelType
        +Int capacity
        +Float cargoLimit
        +calculateRentalCost(days) Float
    }
    
    class Bike {
        +String fuelType
        +Int capacity
        +calculateRentalCost(days) Float
    }
    
    %% Composition and Association Classes
    class Rental {
        +String rentalID
        +Date startDate
        +Date endDate
        +Float rentalFee
        +Vehicle vehicle
        +Customer customer
        +calculateTotalCost() Float
        +extendRental(Date) Boolean
    }
    
    class MaintenanceLog {
        +String logID
        +Vehicle vehicle
        +Date date
        +String description
        +markComplete() Boolean
    }
    classDiagram
    %% Abstract Classes
    class Person {
        <<abstract>>
        +String name
        +String address
        +String phone
        +String email
    }
    
    class Vehicle {
        <<abstract>>
        +String vehicleID
        +String make
        +String model
        +Int year
        +String status
        +display() String
        +getDetails() String
    }
    
    %% Inheritance from Person
    Person <|-- Customer
    Person <|-- Employee
    
    class Customer {
        +String customerID
        +String licenseNumber
        +rentVehicle(Vehicle) Rental
        +returnVehicle(Rental) Boolean
    }
    
    class Employee {
        +String employeeID
        +String position
        +processRental(Rental) Boolean
        +recordMaintenance(Vehicle, String) MaintenanceLog
    }
    
    %% Inheritance from Vehicle
    Vehicle <|-- Car
    Vehicle <|-- Truck
    Vehicle <|-- Bike
    
    class Car {
        +String fuelType
        +Int capacity
        +Float trunkSize
        +calculateRentalCost(days) Float
    }
    
    class Truck {
        +String fuelType
        +Int capacity
        +Float cargoLimit
        +calculateRentalCost(days) Float
    }
    
    class Bike {
        +String fuelType
        +Int capacity
        +calculateRentalCost(days) Float
    }
    
    %% Composition and Association Classes
    class Rental {
        +String rentalID
        +Date startDate
        +Date endDate
        +Float rentalFee
        +Vehicle vehicle
        +Customer customer
        +calculateTotalCost() Float
        +extendRental(Date) Boolean
    }
    
    class MaintenanceLog {
        +String logID
        +Vehicle vehicle
        +Date date
        +String description
        +markComplete() Boolean
    }
    
    class Payment {
        +String paymentID
        +Rental rental
        +Float amount
        +String method
        +Date paymentDate
        +processPayment() Boolean
        +generateReceipt() String
    }
    
    %% Relationships
    Customer "1" -- "0..*" Rental : makes
    Vehicle "1" -- "0..*" Rental : assigned to
    Vehicle "1" -- "0..*" MaintenanceLog : has
    Employee "1" -- "0..*" MaintenanceLog : records
    Rental "1" -- "0..1" Payment : paid byclassDiagram
    %% Abstract Classes
    class Person {
        <<abstract>>
        +String name
        +String address
        +String phone
        +String email
    }
    
    class Vehicle {
        <<abstract>>
        +String vehicleID
        +String make
        +String model
        +Int year
        +String status
        +display() String
        +getDetails() String
    }
    
    %% Inheritance from Person
    Person <|-- Customer
    Person <|-- Employee
    
    class Customer {
        +String customerID
        +String licenseNumber
        +rentVehicle(Vehicle) Rental
        +returnVehicle(Rental) Boolean
    }
    
    class Employee {
        +String employeeID
        +String position
        +processRental(Rental) Boolean
        +recordMaintenance(Vehicle, String) MaintenanceLog
    }
    
    %% Inheritance from Vehicle
    Vehicle <|-- Car
    Vehicle <|-- Truck
    Vehicle <|-- Bike
    
    class Car {
        +String fuelType
        +Int capacity
        +Float trunkSize
        +calculateRentalCost(days) Float
    }
    
    class Truck {
        +String fuelType
        +Int capacity
        +Float cargoLimit
        +calculateRentalCost(days) Float
    }
    
    class Bike {
        +String fuelType
        +Int capacity
        +calculateRentalCost(days) Float
    }
    
    %% Composition and Association Classes
    class Rental {
        +String rentalID
        +Date startDate
        +Date endDate
        +Float rentalFee
        +Vehicle vehicle
        +Customer customer
        +calculateTotalCost() Float
        +extendRental(Date) Boolean
    }
    
    class MaintenanceLog {
        +String logID
        +Vehicle vehicle
        +Date date
        +String description
        +markComplete() Boolean
    }
    
    class Payment {
        +String paymentID
        +Rental rental
        +Float amount
        +String method
        +Date paymentDate
        +processPayment() Boolean
        +generateReceipt() String
    }
    
    %% Relationships
    Customer "1" -- "0..*" Rental : makes
    Vehicle "1" -- "0..*" Rental : assigned to
    Vehicle "1" -- "0..*" MaintenanceLog : has
    Employee "1" -- "0..*" MaintenanceLog : records
    Rental "1" -- "0..1" Payment : paid by
    class Payment {
        +String paymentID
        +Rental rental
        +Float amount
        +String method
        +Date paymentDate
        +processPayment() Boolean
        +generateReceipt() String
    }
    
    %% Relationships
    Customer "1" -- "0..*" Rental : makes
    Vehicle "1" -- "0..*" Rental : assigned to
    Vehicle "1" -- "0..*" MaintenanceLog : has
    Employee "1" -- "0..*" MaintenanceLog : records
    Rental "1" -- "0..1" Payment : paid by
# Out:
#   Cell In[1], line 2
#     get_ipython().run_line_magic('%', 'Abstract Classes')
#     ^
# IndentationError: unexpected indent
